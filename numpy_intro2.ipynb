# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(2,20,1000)

# %%
m,c = 3,10

# %%
y  = m*x + c

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
noise = np.random.randn(1000)

y_mod = y + noise

# %%
plt.scatter(x,y_mod)

# %%
x = np.random.randn(10000)

# %%
out = plt.hist(x,bins=120)

# %%
out = plt.pie([10,20,40],explode=[.1,0,.1])
